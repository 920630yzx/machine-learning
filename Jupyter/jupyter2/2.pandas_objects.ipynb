# %% [markdown]
# 将鱼图像数据进行操作，使用numpy知识

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
fish = plt.imread("./fish.png")
plt.imshow(fish)

# %%
#彩色照片是三维的数据或者是四维
#查看数据类型
fish.shape
# Out:
# (243, 326, 3)

# %%
fish
# Out:
# array([[[0.29411766, 0.39215687, 0.46666667],
#         [0.46666667, 0.4862745 , 0.49803922],
#         [0.4627451 , 0.4862745 , 0.5019608 ],
#         ...,
#         [0.4627451 , 0.48235294, 0.49803922],
#         [0.45882353, 0.47843137, 0.49803922],
#         [0.21960784, 0.33333334, 0.44313726]],
#
#        [[0.2901961 , 0.3764706 , 0.44313726],
#         [0.627451  , 0.6156863 , 0.60784316],
#         [0.85490197, 0.85490197, 0.84705883],
#         ...,
#         [0.8627451 , 0.85882354, 0.8509804 ],
#         [0.8509804 , 0.8509804 , 0.84313726],
#         [0.30588236, 0.42352942, 0.5254902 ]],
#
#        [[0.28235295, 0.37254903, 0.4392157 ],
#         [0.6666667 , 0.6627451 , 0.654902  ],
#         [1.        , 1.        , 1.        ],
#         ...,
#         [1.        , 1.        , 1.        ],
#         [1.        , 1.        , 1.        ],
#         [0.35686275, 0.4745098 , 0.5764706 ]],
#
#        ...,
#
#        [[0.4509804 , 0.45882353, 0.45882353],
# ...

# %%
#彩色照片是一个三维的，黑白照片是一个二维的数据
#需求：把这个彩色的鱼的照片变成黑白的鱼的照片，？？
#三维数据变成二维的数据即可
fish1 = fish[::,::,0]
fish1.shape
# Out:
# (243, 326)

# %%
plt.imshow(fish1,cmap = "gray")

# %%
#把鱼的图片进行上下颠倒
plt.imshow(fish[::-1,::-1,::])

# %%
sanpang
# Out:
# array([[[244, 225, 220],
#         [244, 225, 220],
#         [244, 225, 220],
#         ...,
#         [250, 241, 231],
#         [250, 241, 231],
#         [250, 241, 231]],
#
#        [[244, 225, 220],
#         [244, 225, 220],
#         [244, 225, 220],
#         ...,
#         [250, 241, 231],
#         [250, 241, 231],
#         [250, 241, 231]],
#
#        [[244, 225, 220],
#         [244, 225, 220],
#         [244, 225, 220],
#         ...,
#         [250, 241, 231],
#         [250, 241, 231],
#         [250, 241, 231]],
#
#        ...,
#
#        [[130, 108,  83],
#         [126, 104,  79],
#         [126, 104,  79],
#         ...,
#         [159, 147, 123],
#         [173, 161, 137],
#         [196, 184, 160]],
#
#        [[159, 137, 112],
#         [147, 125, 100],
#         [146, 124,  99],
#         ...,
#         [129, 118,  96],
#         [156, 145, 123],
#         [199, 188, 166]],
#
#        [[176, 154, 129],
#         [159, 137, 112],
#         [156, 134, 109],
# ...

# %%
sanpang[::,::,::-1]
# Out:
# array([[[220, 225, 244],
#         [220, 225, 244],
#         [220, 225, 244],
#         ...,
#         [231, 241, 250],
#         [231, 241, 250],
#         [231, 241, 250]],
#
#        [[220, 225, 244],
#         [220, 225, 244],
#         [220, 225, 244],
#         ...,
#         [231, 241, 250],
#         [231, 241, 250],
#         [231, 241, 250]],
#
#        [[220, 225, 244],
#         [220, 225, 244],
#         [220, 225, 244],
#         ...,
#         [231, 241, 250],
#         [231, 241, 250],
#         [231, 241, 250]],
#
#        ...,
#
#        [[ 83, 108, 130],
#         [ 79, 104, 126],
#         [ 79, 104, 126],
#         ...,
#         [123, 147, 159],
#         [137, 161, 173],
#         [160, 184, 196]],
#
#        [[112, 137, 159],
#         [100, 125, 147],
#         [ 99, 124, 146],
#         ...,
#         [ 96, 118, 129],
#         [123, 145, 156],
#         [166, 188, 199]],
#
#        [[129, 154, 176],
#         [112, 137, 159],
#         [109, 134, 156],
# ...

# %%
#cv2人脸更换
#算法别人已经写好的
#cv这个包需要安装
#安装这个包 opencv
#第二种安装方式：在小黑屏里面输入  pip install opencv-python 这个命令也是可以安装opencv这个包
#opencv:计算机视觉库（内容很多，买本书你可以看一下， python） 图片，等
import cv2
#RGB  ,CV2在读数据的时候，BGR格式的数据
sanpang = cv2.imread("./cv2_change_head/jinzhengen.jpg")
plt.imshow(sanpang[::,::,::-1])


#计算机视觉库里面用来识别人脸的类库
cascade = cv2.CascadeClassifier()

#要拿这个对象加载一下咱们识别人脸的算法  xml文件
cascade.load("./cv2_change_head/haarcascade_frontalface_default.xml")

#拿这个类进行人脸识别
face = cascade.detectMultiScale(sanpang)
face
# Out:
# array([[225,  76,  72,  72]], dtype=int32)

# %%
dog = cv2.imread("./cv2_change_head/dog.jpg")
dog.shape
samll_dog = cv2.resize(dog,(72,72))
samll_dog.shape
# Out:
# (72, 72, 3)

# %%
#[[225,  76,  72,  72]]
for (h,w,p,p) in face:
    sanpang[w:w+p,h:h+p] = samll_dog
    
plt.imshow(sanpang[::,::,::-1])

# %%
#以上的例子就是为了回顾一下numpy

# %% [markdown]
# # Pandas的数据结构

# %% [markdown]
# 导入pandas：
# 三剑客

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1、Series

# %% [markdown]
# Series是一种类似与一维数组的对象，由下面两个部分组成：
# - values：一组数据（ndarray类型）
# - index：相关的数据索引标签

# %%
#一定要注意一下：index , value

# %% [markdown]
# #### 1）Series的创建

# %% [markdown]
# 两种创建方式：
#
# (1) 由列表或numpy数组创建
#
#     默认索引为0到N-1的整数型索引

# %%
nd = np.array([1,2,3,4])
nd
# Out:
# array([1, 2, 3, 4])

# %%
s = Series(nd)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
type(s)
#查看类型的方法  type
# Out:
# pandas.core.series.Series

# %%
s  = Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#指定索引,
s = Series(nd, index = list("abcd"))
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int32

# %%
#索引可不可以相同？？？  Series是可以的
s = Series(nd, index = list("AAAA"))
s
# Out:
# A    1
# A    2
# A    3
# A    4
# dtype: int32

# %%
s["A"]
# Out:
# A    1
# A    2
# A    3
# A    4
# dtype: int32

# %%
#Data must be 1-dimensional
#Series的数据，只能是一维数组，不能是二维的或者多维的数据
s = Series(data = np.random.randint(0,100,size = 10), index= list('abcdefghik'))
s
#DataFrame 是专门用来处理二维数据的
# Out:
# a    31
# b    88
# c    55
# d    88
# e    10
# f    16
# g    84
# h    66
# i    88
# k    70
# dtype: int32

# %% [markdown]
#     还可以通过设置index参数指定索引

# %%
#修改索引, 把小写的行索引变成大写的行索引？？？
s.index = list("ABCDEFGHIK")
s
# Out:
# A    31
# B    88
# C    55
# D    88
# E    10
# F    16
# G    84
# H    66
# I    88
# K    70
# dtype: int32

# %%
#能单个修改吗？？？ 不能的Index does not support mutable operations

s.index[0] = "a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-349325012d21> in <module>()
#       1 #能单个修改吗？？？ 不能的
# ----> 2 s.index[0] = "a"
#
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    1722
#    1723     def __setitem__(self, key, value):
# -> 1724         raise TypeError("Index does not support mutable operations")
#    1725
#    1726     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# 特别地，由ndarray创建的是引用，而不是副本。对Series元素的改变也会改变原来的ndarray对象中的元素。（列表没有这种情况）

# %%
nd = np.array([0,2,4,6])
s = Series(nd, index = ["A","B","C","D"])
s
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-05c4e9e20c53> in <module>()
#       1 nd = np.array([0,2,4,6])
# ----> 2 s = Series(nd, index = ["A","B","C","D","e"])
#       3 s
#
# C:\anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     264                                        raise_cast_failure=True)
#     265
# --> 266                 data = SingleBlockManager(data, index, fastpath=True)
#     267
#     268         generic.NDFrame.__init__(self, data, fastpath=True)
#
# C:\anaconda\lib\site-packages\pandas\core\internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4400         if not isinstance(block, Block):
#    4401             block = make_block(block, placement=slice(0, len(axis)), ndim=1,
# -> 4402                                fastpath=True)
#    4403
# ...

# %%
s["D"] = 16

# %%
s
# Out:
# A     0
# B     2
# C     4
# D    16
# dtype: int32

# %%
nd
# Out:
# array([ 0,  2,  4, 16])

# %% [markdown]
# (2) 由字典创建

# %%
#第二种创建Sereis的方式
s = Series(data = {"a":10,'pi':3.14,"e":2.713,"g":0.618,"kk":89,"u":22,"y":12}, index = ["a","pi","e","g","kk","u","y"])
s
#nan  叫空值  
#注意：ndarray和字典创建的时候，他们的额是不一样的  字典创建的时候index可以多可以少 多补上NAN空值
# Out:
# a     10.000
# pi     3.140
# e      2.713
# g      0.618
# kk    89.000
# u     22.000
# y     12.000
# dtype: float64

# %%
#以上是如何创建Series

# %% [markdown]
# ============================================
#
# 练习1：
#
# 使用多种方法创建以下Series，命名为s1：
# 语文 150
# 数学 150
# 英语 150
# 理综 300
#
# ============================================

# %% [markdown]
# #### 2）Series的索引和切片

# %% [markdown]
# 可以使用中括号取单个索引（此时返回的是元素类型），或者中括号里一个列表取多个索引（此时返回的仍然是一个Series类型）。分为显示索引和隐式索引：
#
# (1) 显式索引：
#
#     - 使用index中的元素作为索引值
#     - 使用.loc[]（推荐）
#
#  注意，此时是闭区间

# %%
s
# Out:
# a     10.000
# pi     3.140
# e      2.713
# g      0.618
# kk    89.000
# u     22.000
# y     12.000
# dtype: float64

# %%
s["pi"]
#元素类型的数据
# Out:
# 3.14

# %%
s["pi","e"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2565             try:
# -> 2566                 return libts.get_value_box(s, key)
#    2567             except IndexError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box()
#
# TypeError: 'tuple' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-dbf423fd7983> in <module>()
# ----> 1 s["pi","e"]
#
# C:\anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# ...

# %%
s[["pi", "e"]]
#返回的数据是Series
# Out:
# pi    3.140
# e     2.713
# dtype: float64

# %%
#.loc函数也可以进行索引（推荐使用）
s.loc["pi"]
#元素的类型
# Out:
# 3.14

# %%
s.loc[["pi","e"]]
#Sereis
# Out:
# pi    3.140
# e     2.713
# dtype: float64

# %%
s.loc[["pi"]]
#Series
# Out:
# pi    3.14
# dtype: float64

# %%
#单个索引的时候，index值，loc 此时返回的是元素的类型，   多个元素进行索引的时候：在一个中括号之上在加9一个中括号， 此时返回的是Series

# %% [markdown]
# (2) 隐式索引：
#
#     - 使用整数作为索引值
#     - 使用.iloc[]（推荐）
#
#  注意，此时是半开区间

# %%
s[1]
# Out:
# 3.14

# %%
s.iloc[1]
# Out:
# 3.14

# %%
s.iloc[[1]]
# Out:
# pi    3.14
# dtype: float64

# %%
s.iloc[[1,2]]
# Out:
# pi    3.140
# e     2.713
# dtype: float64

# %%
#以上是索引
#下面看一下切片
#左闭右闭一种情况，进行切片
s["a":"e"]
# Out:
# a     10.000
# pi     3.140
# e      2.713
# dtype: float64

# %%
s.loc["a":"g"]
# Out:
# a     10.000
# pi     3.140
# e      2.713
# g      0.618
# dtype: float64

# %%
s.iloc[0:2]
#左闭右开的一种情况
# Out:
# a     10.00
# pi     3.14
# dtype: float64

# %%
#切片操作的时候， loc或者是[]  切片的效果都是左闭右闭的一种情况， iloc切片的时候，左闭右开的一种情况

# %% [markdown]
# ============================================
#
# 练习2：
#
# 使用多种方法对练习1创建的Series s1进行索引和切片：
#
# 索引：
# 数学 150
#
# 切片：
# 语文 150
# 数学 150
# 英语 150
#
# ============================================

# %% [markdown]
# #### 3）Series的基本概念

# %% [markdown]
# 可以把Series看成一个定长的有序字典

# %% [markdown]
# 可以通过shape，size，index,values等得到series的属性

# %%
s
# Out:
# a     10.000
# pi     3.140
# e      2.713
# g      0.618
# kk    89.000
# u     22.000
# y     12.000
# dtype: float64

# %%
s.shape
#(2,3)二维的数据 （1,2,3）三维的
# Out:
# (7,)

# %%
s.size
# Out:
# 7

# %%
s.index
# Out:
# Index(['a', 'pi', 'e', 'g', 'kk', 'u', 'y'], dtype='object')

# %%
s.values
# Out:
# array([10.   ,  3.14 ,  2.713,  0.618, 89.   , 22.   , 12.   ])

# %% [markdown]
# 可以通过head(),tail()快速查看Series对象的样式

# %%
s
# Out:
# a     10.000
# pi     3.140
# e      2.713
# g      0.618
# kk    89.000
# u     22.000
# y     12.000
# dtype: float64

# %%
s.head(3)
#head方法是取出来前5条数据， 还可以根据里面的参数不同来取咱们的数据
# Out:
# a     10.000
# pi     3.140
# e      2.713
# dtype: float64

# %%
s.tail(2)
# Out:
# u    22.0
# y    12.0
# dtype: float64

# %% [markdown]
# 当索引没有对应的值时，可能出现缺失数据显示NaN（not a number）的情况

# %%
s = Series(data = {"a":10,"b":20,"c":30}, index = list("abcd"))
s
# Out:
# a    10.0
# b    20.0
# c    30.0
# d     NaN
# dtype: float64

# %% [markdown]
# 可以使用pd.isnull()，pd.notnull()，或自带isnull(),notnull()函数检测缺失数据

# %%
#重要：
pd.isnull(s)
#返回值是boolean 类型的数据  如果是空值的话，就返回True  如果是非空的返回False
# Out:
# a    False
# b    False
# c    False
# d     True
# dtype: bool

# %%
pd.notnull(s)
#如果是空值的话，就是一个False 非空值就是一个True
# Out:
# a     True
# b     True
# c     True
# d    False
# dtype: bool

# %%
ind = s.isnull()
ind
# Out:
# a    False
# b    False
# c    False
# d     True
# dtype: bool

# %%
#非常重要的
#为空数据，进行赋值

s[ind] = 1000

# %%
s
# Out:
# a      10.0
# b      20.0
# c      30.0
# d    1000.0
# dtype: float64

# %% [markdown]
# Series对象本身及其实例都有一个name属性

# %%
s = Series(data = np.random.randint(0,150,size  =5), index = ["张三","李四","Sara","Lisa","Machel"])
s.name = "Python"
s
# Out:
# 张三         66
# 李四         78
# Sara      146
# Lisa      124
# Machel      5
# Name: Python, dtype: int32

# %%
s2 = Series([99,120,131,147], index = list("abcd"), name = "数学")
s2
# Out:
# a     99
# b    120
# c    131
# d    147
# Name: 数学, dtype: int64

# %% [markdown]
# #### 4）Series的运算

# %% [markdown]
# (1) 适用于numpy的数组运算也适用于Series

# %%
s
# Out:
# 张三         66
# 李四         78
# Sara      146
# Lisa      124
# Machel      5
# Name: Python, dtype: int32

# %%
s2 = s + 20
s2
# Out:
# 张三         86
# 李四         98
# Sara      166
# Lisa      144
# Machel     25
# Name: Python, dtype: int32

# %%
#Sereis加减乘除的运算，可以使用运算符，也可以使用系统给咱们提供的封装好的额函数
s.add(20)
# Out:
# 张三         86
# 李四         98
# Sara      166
# Lisa      144
# Machel     25
# Name: Python, dtype: int32

# %%
s.subtract(20)
#减法
# Out:
# 张三         46
# 李四         58
# Sara      126
# Lisa      104
# Machel    -15
# Name: Python, dtype: int32

# %%
s.multiply(2)
#乘法
# Out:
# 张三        132
# 李四        156
# Sara      292
# Lisa      248
# Machel     10
# Name: Python, dtype: int32

# %%
s.divide(2)
#除法
# Out:
# 张三        33.0
# 李四        39.0
# Sara      73.0
# Lisa      62.0
# Machel     2.5
# Name: Python, dtype: float64

# %%
#咱们的一个Series和一个数据进行运算

# %% [markdown]
# (2) Series之间的运算
#
# - 在运算中自动对齐不同索引的数据
# - 如果索引不对应，则补NaN

# %%
s1 = Series(np.random.randint(0,150,size = 4), index = ["A","B","C","Sara"],name = "数学")
s1
# Out:
# A       142
# B       148
# C        69
# Sara    120
# Name: 数学, dtype: int32

# %%
s2
# Out:
# 张三         86
# 李四         98
# Sara      166
# Lisa      144
# Machel     25
# Name: Python, dtype: int32

# %%
3 + np.nan
# Out:
# nan

# %%
s1+s2
# Out:
# A           NaN
# B           NaN
# C           NaN
# Lisa        NaN
# Machel      NaN
# Sara      286.0
# 张三          NaN
# 李四          NaN
# dtype: float64

# %% [markdown]
# - 注意：要想保留所有的index，则需要使用.add()函数

# %%
s1
# Out:
# A       142
# B       148
# C        69
# Sara    120
# Name: 数学, dtype: int32

# %%
s2
# Out:
# 张三         86
# 李四         98
# Sara      166
# Lisa      144
# Machel     25
# Name: Python, dtype: int32

# %%
s3  = s1.add(s2, fill_value=2)
s3
# Out:
# A         144.0
# B         150.0
# C          71.0
# Lisa      146.0
# Machel     27.0
# Sara      286.0
# 张三         88.0
# 李四        100.0
# dtype: float64

# %% [markdown]
# ============================================
#
# 练习3：
#
# 1. 想一想Series运算和ndarray运算的规则有什么不同？
#
# 2. 新建另一个索引包含“文综”的Series s2，并与s2进行多种算术操作。思考如何保存所有数据。
#
# ============================================

# %% [markdown]
# ### 2、DataFrame

# %% [markdown]
# DataFrame是一个【表格型】的数据结构，可以看做是【由Series组成的字典】（共用同一个索引）。DataFrame由按一定顺序排列的多列数据组成。设计初衷是将Series的使用场景从一维拓展到多维。DataFrame既有行索引，也有列索引。
# - 行索引：index
# - 列索引：columns
# - 值：values（numpy的二维数组）

# %%
#index  columns   values

# %% [markdown]
# #### 1）DataFrame的创建
# 最常用的方法是传递一个字典来创建。DataFrame以字典的键作为每一【列】的名称，以字典的值（一个数组）作为每一列。
#
# 此外，DataFrame会自动加上每一行的索引（和Series一样）。
#
# 同Series一样，若传入的列与字典的键不匹配，则相应的值为NaN。

# %%
df1 = DataFrame(data = {"Python":[99,101,120,78],
                        "数学":[120,136,141,149],
                       "汉语":[123,114,130,117]}, index = list("abcd"))
df1
# Out:
#    Python   数学   汉语
# a      99  120  123
# b     101  136  114
# c     120  141  130
# d      78  149  117

# %%
df1 = DataFrame(data = {"Python":[99,101,120,78],
                        "数学":[120,136,141,149],
                       "汉语":[123,114,130,117]}, index = list("abcde"))
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4637         blocks = form_blocks(arrays, names, axes)
# -> 4638         mgr = BlockManager(blocks, axes)
#    4639         mgr._consolidate_inplace()
#
# C:\anaconda\lib\site-packages\pandas\core\internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    3032         if do_integrity_check:
# -> 3033             self._verify_integrity()
#    3034
#
# C:\anaconda\lib\site-packages\pandas\core\internals.py in _verify_integrity(self)
#    3243             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3244                 construction_error(tot_items, block.shape[1:], self.axes)
#    3245         if len(self.items) != tot_items:
#
# ...

# %%
df1 = DataFrame(data = {"Python":[99,101,120,78],
                        "数学":[120,136,141,149],
                       "汉语":[123,114,130,117]}, index = list("abcd"), 
               columns = ["Python","数学","汉语","英语"])
df1
#列比行更加重要的
# Out:
#    Python   数学   汉语   英语
# a      99  120  123  NaN
# b     101  136  114  NaN
# c     120  141  130  NaN
# d      78  149  117  NaN

# %% [markdown]
# DataFrame属性：values、columns、index、shape

# %%
df1.values
# Out:
# array([[99, 120, 123, nan],
#        [101, 136, 114, nan],
#        [120, 141, 130, nan],
#        [78, 149, 117, nan]], dtype=object)

# %%
df1.columns
#列索引
# Out:
# Index(['Python', '数学', '汉语', '英语'], dtype='object')

# %%
df1.index
#行索引
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df1.shape
# Out:
# (4, 4)

# %% [markdown]
# #

# %%
df2 = DataFrame(data = np.random.randint(0,150,size = (4,4)), 
               index = list("abcd"), columns = ["Python","Java","Ruby","Html"])
df2
# Out:
#    Python  Java  Ruby  Html
# a      51    18    63    75
# b      82    99   122   110
# c       1   133    21    38
# d      89   132     9   146

# %% [markdown]
# ============================================
#
# 练习4：
#
# 根据以下考试成绩表，创建一个DataFrame，命名为df：
# ```
#     张三  李四
# 语文 150  0
# 数学 150  0
# 英语 150  0
# 理综 300  0
# ```
#
# ============================================

# %% [markdown]
# #### 2）DataFrame的索引

# %% [markdown]
# (1) 对列进行索引
#
#     - 通过类似字典的方式
#     - 通过属性的方式
#
#  可以将DataFrame的列获取为一个Series。返回的Series拥有原DataFrame相同的索引，且name属性也已经设置好了，就是相应的列名。

# %%
df2
# Out:
#    Python  Java  Ruby  Html
# a      51    18    63    75
# b      82    99   122   110
# c       1   133    21    38
# d      89   132     9   146

# %%
df2["Python"]
#返回的是一个Series数据
#因为其实DataFrame是由多个Sereis组成的数据
# Out:
# a    51
# b    82
# c     1
# d    89
# Name: Python, dtype: int32

# %%
df2.Python
# Out:
# a    51
# b    82
# c     1
# d    89
# Name: Python, dtype: int32

# %%
df2[["Python","Java"]]
#数据类型还是一个DataFrame
# Out:
#    Python  Java
# a      51    18
# b      82    99
# c       1   133
# d      89   132

# %% [markdown]
# (2) 对行进行索引
#
#     - 使用.loc[]加index来进行行索引
#     - 使用.iloc[]加整数来进行行索引
#
#  同样返回一个Series，index为原来的columns。

# %% [markdown]
# (3) 对元素索引的方法
#     - 使用列索引
#     - 使用行索引(iloc[3,1]相当于两个参数;iloc[[3,3]] 里面的[3,3]看做一个参数)
#     - 使用values属性（二维numpy数组）

# %% [markdown]
# 【注意】
# 直接用中括号时：
# - 索引表示的是列索引
# - 切片表示的是行切片

# %% [markdown]
# ============================================
#
# 练习5：
#
# 使用多种方法对ddd进行索引和切片，并比较其中的区别
#
# ============================================

# %% [markdown]
# #### 3）DataFrame的运算

# %% [markdown]
# （1） DataFrame之间的运算
#
# 同Series一样：
#
# - 在运算中自动对齐不同索引的数据
# - 如果索引不对应，则补NaN

# %% [markdown]
# 创建DataFrame df1 不同人员的各科目成绩，月考一

# %% [markdown]
# 创建DataFrame df2 不同人员的各科目成绩，月考二
# 有新学生转入

# %% [markdown]
# 下面是Python 操作符与pandas操作函数的对应表：
#
# | Python Operator | Pandas Method(s)                      |
# |-----------------|---------------------------------------|
# | ``+``           | ``add()``                             |
# | ``-``           | ``sub()``, ``subtract()``             |
# | ``*``           | ``mul()``, ``multiply()``             |
# | ``/``           | ``truediv()``, ``div()``, ``divide()``|
# | ``//``          | ``floordiv()``                        |
# | ``%``           | ``mod()``                             |
# | ``**``          | ``pow()``                             |

# %% [markdown]
# （2） Series与DataFrame之间的运算
#
# 【重要】
#
# - 使用Python操作符：以行为单位操作（参数必须是行），对所有行都有效。（类似于numpy中二维数组与一维数组的运算，但可能出现NaN）
#
# - 使用pandas操作函数：
#
#         axis=0：以列为单位操作（参数必须是列），对所有列都有效。
#         axis=1：以行为单位操作（参数必须是行），对所有行都有效。

# %% [markdown]
# ============================================
#
# 练习6：
#
# 1. 假设ddd是期中考试成绩，ddd2是期末考试成绩，请自由创建ddd2，并将其与ddd相加，求期中期末平均值。
#
# 2. 假设张三期中考试数学被发现作弊，要记为0分，如何实现？
#
# 3. 李四因为举报张三作弊立功，期中考试所有科目加100分，如何实现？
#
# 4. 后来老师发现有一道题出错了，为了安抚学生情绪，给每位学生每个科目都加10分，如何实现？
#
# ============================================
