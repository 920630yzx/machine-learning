# %%
import scipy.misc as misc
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

zhima  = plt.imread('G:/python doc/spyder picture/芝麻.jpg')
zhima.shape
plt.imshow(zhima)

# %%
zhima_noisy = zhima.copy().astype(float)  # 调整元素的格式
plt.imshow(zhima_noisy)  # 调整元素的格式，图片发生细微的变化
np.random.standard_normal(zhima_noisy.shape).min()
np.random.standard_normal(zhima_noisy.shape).max()
# Out:
# 4.892927557235077

# %%
face_g = misc.face(gray=False)

plt.imshow(face_g,cmap = 'gray')
face_g
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
im_data  = plt.imread('芝麻.jpg')
im_data.shape
# Out:
# (662, 1000, 3)

# %%
plt.imshow(im_data)

# %% [markdown]
# ### 图片灰度处理

# %% [markdown]
# 三种方法

# %%
# (662, 1000, 3) --->(662,1000)
#使用最大值发
im_data[0,0]

im_data1 = im_data.max(axis = 2)
im_data1.shape
plt.imshow(im_data1,cmap = 'gray')

# %%
#求平均值
im_data2 = im_data.mean(axis=-1)
im_data2.shape
plt.imshow(im_data2,cmap = 'gray')

# %%
import numpy as np

# %%
#红绿蓝的权重
a = np.array([0.299,0.587,0.114])
#red*0.299+green*0.587+blue*0.114
#矩阵乘法
im_data3 = np.dot(im_data,a)
im_data3.shape
plt.imshow(im_data3,cmap = "gray")

# %% [markdown]
# # matplotlib

# %% [markdown]
# ## 目录
# + 一、【重点】Matplotlib基础知识
#
# + 二、设置plot的风格和样式
#     + 1、【重点】点和线的样式
#     + 2、X、Y轴坐标刻度
#
#
# + 三、2D图形
#     + 1、示例
#     + 2、【重点】直方图
#     + 3、【重点】条形图
#     + 4、【重点】饼图
#     + 5、【重点】散点图
#
# =============以上为重点=================
#
# #### 下面的自学
# + 四、图形内的文字、注释、箭头
#     + 1、图形内的文字
#     + 2、注释
#     + 3、箭头
#
# + 五、3D图
#     + 1、曲面图

# %% [markdown]
# ## 一、Matplotlib基础知识

# %% [markdown]
# Matplotlib中的基本图表包括的元素
# + x轴和y轴
# 水平和垂直的轴线
#
#
# + x轴和y轴刻度
# 刻度标示坐标轴的分隔，包括最小刻度和最大刻度
#
#
# + x轴和y轴刻度标签
# 表示特定坐标轴的值
#
#
# + 绘图区域
# 实际绘图的区域

# %% [markdown]
# ### 只含单一曲线的图

# %%
x = np.linspace(0,10,10)
#plot参数只有一个，x轴坐标默认从0,1,2……
plt.plot(x,x**2)

# %% [markdown]
# ### 包含多个曲线的图

# %% [markdown]
# 1、可以使用多个plot函数（推荐），在一个图中绘制多个曲线

# %%
x = np.arange(0,10,1)
plt.plot(x,x*2)
plt.plot(x,x/2)
plt.plot(x,x**2)

# %% [markdown]
# 2、也可以在一个plot函数中传入多对X,Y值，在一个图中绘制多个曲线

# %%
x = np.arange(0,10,1)
plt.plot(x,x**2,x,5*x,x,x/3)

# %% [markdown]
# ### 网格线
# 绘制正选余弦

# %% [markdown]
# 使用plt.grid(True)方法为图添加网格线

# %%
x = np.arange(-np.pi,np.pi,0.01)
plt.plot(x,np.sin(x),x,np.cos(x))
plt.grid(True)

# %% [markdown]
# 设置grid参数（参数与plot函数相同），使用plt面向对象的方法，创建多个子图显示不同网格线
# ![](1.PNG)
#
# - lw代表linewidth，线的粗细
# - alpha表示线的明暗程度
# - color代表颜色

# %%
#plt面向对象
#创建，图形就是所谓的对象
#sub = 子
plt.figure(figsize=(12,9))
axes = plt.subplot(231)
x = np.arange(-20,20,0.1)
axes.grid(color = 'r',linestyle = '--',linewidth = 2)
axes.plot(x,np.sin(x))

axes2 = plt.subplot(232)
x2 = np.arange(-20,20,0.1)
axes2.grid(color = 'g',linestyle = '-.')
axes2.plot(x2,np.cos(x2))


axes3 = plt.subplot(233)
axes3.grid(color = 'blue',linestyle = '--',linewidth = 2)
axes3.plot(x,np.sin(x))
#///////////////////////////////////////////////////

axes4 = plt.subplot(234)
x = np.arange(-20,20,0.1)
axes4.grid(color = 'r',linestyle = '--',linewidth = 2)
axes4.plot(x,np.sin(x))

axes5 = plt.subplot(235)
x2 = np.arange(-20,20,0.1)
axes5.grid(color = 'g',linestyle = '-.')
axes5.plot(x2,np.cos(x2))


axes6 = plt.subplot(236)
axes6.grid(color = 'blue',linestyle = '--',linewidth = 2)
axes6.plot(x,np.sin(x))

# %% [markdown]
# ### 坐标轴界限

# %% [markdown]
# #### axis方法
# 如果axis方法没有任何参数，则返回当前坐标轴的上下限axis(xmin =,ymax = )

# %%
x = np.random.randn(10)
#raise ValueError('v must contain [xmin xmax ymin ymax]')
plt.axis([-5,15,-5,10])
plt.plot(x)

# %% [markdown]
# ##### plt.axis('xxx') 'tight'、'off'、'equal'……
#
# 设置坐标轴类型
# 关闭坐标轴
# ![](2.png)

# %%
x = np.linspace(-np.pi,np.pi,100)
# plt.figure(figsize=(4,4))
plt.plot(np.sin(x),np.cos(x))

plt.axis('equal')
# Out:
# (-1.0998615404412626,
#  1.0998615404412626,
#  -1.0999748271191592,
#  1.0994713695023444)

# %% [markdown]
# #### xlim方法和ylim方法
#
# 除了plt.axis方法，还可以通过xlim，ylim方法设置坐标轴范围

# %%
y = np.arange(0,10,1)
plt.plot(y)
plt.xlim(-2,12)
plt.ylim(2,10)
# Out:
# (2, 10)

# %% [markdown]
# ### 坐标轴标签
# xlabel方法和ylabel方法
# plt.ylabel('y = x^2 + 5',rotation = 60)旋转

# %%
x = np.arange(0,10,2)
y = x**2+5
plt.plot(x,y)
plt.ylabel('f(x) = x**2+5',rotation = 60,horizontalalignment = 'left')
plt.xlabel('x',fontsize = 20)

# %% [markdown]
# ### 标题
# title方法

# %%
x = np.linspace(-np.pi,np.pi,100)
plt.plot(x,np.sin(x))
plt.title('f(x) = sin(x)',fontsize = 20,loc = 'left')

# %% [markdown]
# ### 图例

# %% [markdown]
# #### legend方法
#
# 两种传参方法：
# - 【推荐使用】在plot函数中增加label参数
# - 在legend方法中传入字符串列表
# ![](3.png)

# %%
x = np.arange(0,10,1)
plt.plot(x,x,x,x*2,x,x/2)
#参数传递需要中括号
plt.legend(['normal','fast','slow'])

# %%
plt.plot(x,x,label = 'normal')
plt.plot(x,x**2,label = 'fast')
plt.plot(x,x/2,label = 'slow')
plt.legend()

# %% [markdown]
# label参数为'_xxx'，则图例中不显示
# plt.plot(x, x*1.5, label = '_xxx')

# %%
plt.plot(x,x,label = 'normal')
plt.plot(x,x**2,label = '_fast')
plt.plot(x,x/2,label = 'slow')
plt.legend()

# %%
x = np.arange(0,10,1)
plt.plot(x,x,x,x*2,x,x/2)
#参数传递需要中括号
plt.legend(['normal','_fast','slow'])

# %% [markdown]
# ### loc参数

# %% [markdown]
# | 字符串       | 数值      | 字符串   |  数值 |
# | :-------------: |:-----------:| :-----:|  :-----:|
# | best        |  0        | center left   |   6 |
# | upper right    | 1        | center right  |   7  |
# | upper left    |  2        | lower center  |   8  |
# | lower left    |  3        | upper center  |   9 |
# | lower right   |  4        | center      |   10 |
# | right       |  5        |

# %%
x = np.arange(0,10,1)
plt.plot(x,x,x,x*2,x,x/2)
#参数传递需要中括号
plt.legend(['normal','_fast','slow'],loc = 0)

# %% [markdown]
# loc参数可以是2元素的元组，表示图例左下角的坐标

# %%
x = np.arange(0,10,1)
plt.plot(x,x,x,x*2,x,x/2)
#参数传递需要中括号
#loc = (0.5,1) 相对值，相对的图片宽高，1个图片的宽度单位
#图例左下角的坐标
plt.legend(['normal','_fast','slow'],loc = (1,0))

# %% [markdown]
# 图例也可以超过图的界限loc = (-0.1,0.9)

# %% [markdown]
# ### ncol参数
# ncol控制图例中有几列

# %%
x = np.arange(0,10,1)
plt.plot(x,x,x,x*2,x,x/2)
#参数传递需要中括号
plt.legend(['normal','_fast','slow'],loc = 0,ncol = 2)

# %% [markdown]
# ### linestyle、color、marker
# 修改线条样式
# ![](4.png)

# %%
x1 = np.random.randn(50)
x2 = np.random.randn(50)
x3 = np.random.randn(50)
plt.plot(x1.cumsum(),c = 'red',linestyle = '--',marker = 'o')
plt.plot(x2.cumsum(),color = 'yellow',linestyle = '-.',marker = '>')
plt.plot(x3.cumsum(),color = 'purple',linestyle =':',marker = '*' )
plt.legend(['x1','x2','x3'])

# %% [markdown]
# ### 保存图片

# %% [markdown]
# figure.savefig的选项
# + filename
# 含有文件路径的字符串或Python的文件型对象。图像格式由文件扩展名推断得出，例如，.pdf推断出PDF，.png推断出PNG
# （“png”、“pdf”、“svg”、“ps”、“eps”……）
# + dpi
# 图像分辨率（每英寸点数），默认为100
# + facecolor
# 图像的背景色，默认为“w”（白色）

# %%
x1 = np.random.randn(50)
x2 = np.random.randn(50)
x3 = np.random.randn(50)
plt.plot(x1.cumsum(),c = 'red',linestyle = '--',marker = 'o')
plt.plot(x2.cumsum(),color = 'yellow',linestyle = '-.',marker = '>')
plt.plot(x3.cumsum(),color = 'purple',linestyle =':',marker = '*' )
plt.legend(['x1','x2','x3'])
plt.savefig('pic4.jpg',dpi = 500,facecolor = 'cyan',papertype = 'letter',orientation = 'landscape')

# %% [markdown]
# ## 二、设置plot的风格和样式
# plot语句中支持除X,Y以外的参数，以字符串形式存在，来控制颜色、线型、点型等要素，语法形式为：
# plt.plot(X, Y, 'format', ...)

# %% [markdown]
# ### 点和线的样式

# %% [markdown]
# #### 颜色
# 参数color或c

# %%
x = np.arange(0,10,0.1)
plt.plot(x,np.sin(x),'r')

# %% [markdown]
# ##### 颜色值的方式
# + 别名
#     + color='r'
#
#
#
# + 合法的HTML颜色名
#     + color = 'red'
#
# | 颜色       | 别名      | HTML颜色名  | 颜色   |  别名 |HTML颜色名|
# | :-------------: |:---------:|:-----------:| :------:|  :-----:| :-----:|
# | 蓝色        | b       | blue      | 绿色   |  g   |  green  |
# | 红色        | r       | red      | 黄色    |  y   |  yellow |
# | 青色        | c       | cyan      | 黑色   |  k   |  black  |
# | 洋红色      | m        | magenta    | 白色   |  w   |  white  |
#
#
#
#
#
#
# + HTML十六进制字符串
#     + color = '#eeefff'
#
#
#
#
# + 归一化到[0, 1]的RGB元组
#     + color = (0.3, 0.3, 0.4)

# %%
x = np.arange(0,10,0.1)
#十六进制表示颜色：8位前两位是透明度
#只能使用6位进行表示，红绿蓝
plt.plot(x,np.sin(x),'#ff0000')

# %%
x = np.arange(0,10,0.1)
#十六进制表示颜色：8位前两位是透明度
#只能使用6位进行表示，红绿蓝
plt.plot(x,np.sin(x),color = (0.8,0.8,0.9))

# %%
#jpg png 区别，格式不同，导致存数据的时候，png：归一化的红绿蓝数据
#jpg 0~255
plt.imread('cat2.png')
# Out:
# array([[[ 0.24313726,  0.23921569,  0.21960784],
#         [ 0.25098041,  0.24705882,  0.22745098],
#         [ 0.25098041,  0.24705882,  0.22745098],
#         ...,
#         [ 0.25098041,  0.24705882,  0.22745098],
#         [ 0.25098041,  0.24705882,  0.22745098],
#         [ 0.24313726,  0.23921569,  0.21960784]],
#
#        [[ 0.23921569,  0.23529412,  0.21960784],
#         [ 0.24705882,  0.24313726,  0.22745098],
#         [ 0.24705882,  0.24313726,  0.22745098],
#         ...,
#         [ 0.24705882,  0.24313726,  0.22745098],
#         [ 0.24705882,  0.24313726,  0.22745098],
#         [ 0.23921569,  0.23529412,  0.21960784]],
#
#        [[ 0.89803922,  0.10196079,  0.92156863],
#         [ 0.85882354,  0.03921569,  0.78823531],
#         [ 0.8509804 ,  0.02352941,  0.68235296],
#         ...,
#         [ 0.18431373,  0.08235294,  0.09411765],
#         [ 0.11764706,  0.00784314,  0.04313726],
#         [ 0.05098039,  0.92941177,  0.94901961]],
#
#        ...,
# ...

# %% [markdown]
# ##### 透明度
# alpha参数

# %%
x = np.arange(0,10,0.1)
#十六进制表示颜色：8位前两位是透明度
#只能使用6位进行表示，红绿蓝
plt.plot(x,np.sin(x),'#ff0000',alpha = 0.5)

# %% [markdown]
# ##### 背景色
# 设置背景色，通过plt.subplot()方法传入facecolor参数，来设置坐标轴的背景色

# %%
x = np.arange(0,10,0.1)
#十六进制表示颜色：8位前两位是透明度
#只能使用6位进行表示，红绿蓝
#面向对象的画图方法
#axes 画板
axes = plt.subplot(facecolor = 'green')
axes.plot(x,np.sin(x),'r')
print(axes)
# Out:
# Axes(0.125,0.125;0.775x0.755)

# %% [markdown]
# #### 线型
# 参数linestyle或ls

# %% [markdown]
# | 线条风格     | 描述      | 线条风格 |  描述 |
# | :-------------: |:------------:| :----:|  :-----:|
# | '-'        | 实线     | ':'     |  虚线 |
# | '--'       | 破折线    | 'steps'  |  阶梯线 |
# | '-.'       | 点划线    | 'None' / '，' |  什么都不画 |

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '-.')

# %% [markdown]
# ##### 线宽
# linewidth或lw参数

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = 'steps',lw = 2)

# %% [markdown]
# ##### 不同宽度的破折线
# dashes参数
# 设置破折号序列各段的宽度
# ![](5.png)

# %%
x = np.arange(-np.pi,np.pi,0.1)
#dashes = [],参数线段长度，间隔，线段的长度
plt.plot(x,np.sin(x),ls = '-.',dashes = [20,50,5,2,10,5])

# %% [markdown]
# #### 点型
# marker参数

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | '1'         | 一角朝下的三脚架      | '3'     |  一角朝左的三脚架 |
# | '2'         | 一角朝上的三脚架      | '4'     |  一角朝右的三脚架 |

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '--',marker = '3')

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 's'         | 正方形   | 'p'   | 五边形     |
# | 'h'         | 六边形1    | 'H'     | 六边形2    |
# | '8'         | 八边形     |

# %%
plt.figure(figsize=(12,9))
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '--',marker = '8',markersize = 15)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | '.'     |  点 | 'x'   | X   |
# | '\*'    |  星号  | '+'         | 加号       |
# | ','         | 像素       |

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '--',marker = '+')

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 'o'         | 圆圈      | 'D'         | 菱形      |
# | 'd'    |  小菱形  |'','None',' ',None| 无       |

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '--',marker = 'None')

# %% [markdown]
# | 标记     | 描述     | 标记   |  描述 |
# | :--------: |:----------:| :------:| :----:|
# | '\_'     |  水平线    | '&#124;'     |  水平线
# ![](6.png)

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '--',marker = '|',markersize = 10)

# %% [markdown]
# | 标记        | 描述       | 标记   |  描述 |
# | :-------------: |:-----------:| :----:|  :-----:|
# | 'v'         | 一角朝下的三角形 | '<'     |  一角朝左的三角形 |
# | '^'         | 一角朝上的三角形 | '>'     |  一角朝右的三角形 |

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),ls = '--',marker = '<')

# %% [markdown]
# #### 多参数连用
# 颜色、点型、线型

# %%
x = np.arange(-np.pi,np.pi,0.1)
plt.plot(x,np.sin(x),'r-.o')

# %% [markdown]
# #### 更多点和线的设置

# %% [markdown]
# | 参数        | 描述       | 参数       |  描述   |
# | :-------------: |:-----------:| :-------------:|  :------:|
# | color或c      | 线的颜色   | linestyle或ls  |  线型   |
# | linewidth或lw   | 线宽     | marker       |  点型  |
# | markeredgecolor  | 点边缘的颜色 | markeredgewidth | 点边缘的宽度 |
# | markerfacecolor  | 点内部的颜色 | markersize    |  点的大小    |
# ![](7.png)

# %%
x = np.arange(0,10,1)
plt.plot(x,'r--',marker = 'o',markersize = 10,markeredgecolor = 'green',
         markeredgewidth = 2,markerfacecolor = 'purple')

# %% [markdown]
# #### 在一条语句中为多个曲线进行设置

# %% [markdown]
# ##### 多个曲线同一设置
# 属性名声明
#
# plt.plot(x1, y1, x2, y2, fmt, ...)

# %%
x = np.arange(0,10,0.01)
#如果设置属性的时候，不声明属性名称，那么这个属性直接被设置给距离它最近的那条线
plt.plot(x,2*x,x,np.sin(x)*5,'r',ls = '--',lw = 3)

# %% [markdown]
# ##### 多个曲线不同设置
# 多个都进行设置时，无需声明属性
# plt.plot(x1, y1, fmt1, x2, y2, fmt2, ...)

# %%
x = np.arange(0,10,0.5)

# %%
len(x)
# Out:
# 20

# %%
plt.plot(x,x,'r--',x,np.cos(x),'g-.',marker = 'o')

# %% [markdown]
# #### 三种设置方式

# %% [markdown]
# ##### 向方法传入关键字参数

# %% [markdown]
# ##### 对实例使用一系列的setter方法

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '2.0.0'

# %%
x = np.arange(0,10,0.1)

# %%
#画板
# axes = plt.subplot()

l, =  plt.plot(x,np.sin(x))
l2, = plt.plot(x,np.cos(x))
l3, = plt.plot(x,x*2)
print(l2)

l.set_color('r')
l2.set_color('purple')
l3.set_linewidth(5)
l3.set_linestyle('--')
# x[0].set_linewidth(5)

# axes.set_title('sin(x)')

# axes.set_facecolor('r')

# line1.set_linewidth(5)


# axes.set_prop_cycle('b')
# axes.set_prop_cycle(line1,'r')
# Out:
# Line2D(_line1)

# %% [markdown]
# ##### 使用setp()方法

# %%
#setp():p:property(属性)

line, = plt.plot(x,np.sin(x))
line2, = plt.plot(x,np.cos(x))
plt.setp(line2,linestyle='--',linewidth = 3,marker = 'o')
# Out:
# [None, None, None]

# %% [markdown]
# ### X、Y轴坐标刻度
# xticks()和yticks()方法
# ![](8.png)

# %%
#总共100个数据
x = np.random.randn(100)
plt.plot(x.cumsum())
plt.xticks(np.linspace(0,100,5),list('ABCDE'),fontsize = 15,rotation = 90)

plt.yticks(np.linspace(-10,20,3),['min',0,'max'],fontsize = 20)
# Out:
# ([<matplotlib.axis.YTick at 0x7fbfa11b1ef0>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# #### 面向对象方法
# set_xticks、set_yticks、set_xticklabels、set_yticklabels方法

# %%
axes = plt.subplot(111)
axes.plot(x.cumsum())

#set_xticks 设置刻度值
axes.set_xticks([0,25,50,75,100])
#set_xticklabels;设置标签
axes.set_xticklabels(list('abcde'))

axes.set_yticks([-10,-5,0,5,10])

# %% [markdown]
# #### 正弦余弦
# LaTex语法，用$\pi$等表达式在图表上写上希腊字母
# ![](9.png)

# %%
len(x)
# Out:
# 629

# %%
x = np.arange(-np.pi,np.pi,0.01)
plt.plot(np.sin(x))
plt.plot(np.cos(x))
plt.yticks([-1,0,1],['min',0,'max'])

plt.xticks([0,157.25,314.5,157.25*3,629],['-$\sigma$','-$\pi/2$',0,'$\pi/2$','$\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fbfa0142048>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# ## 三、2D图形

# %% [markdown]
# ### 直方图
#
# 【直方图的参数只有一个x！！！不像条形图需要传入x,y】
#
# hist()的参数
# + bins
# 可以是一个bin数量的整数值，也可以是表示bin的一个序列。默认值为10
# + normed
# 如果值为True，直方图的值将进行归一化处理，形成概率密度，默认值为False
# + color
# 指定直方图的颜色。可以是单一颜色值或颜色的序列。如果指定了多个数据集合，颜色序列将会设置为相同的顺序。如果未指定，将会使用一个默认的线条颜色
# + orientation
# 通过设置orientation为horizontal创建水平直方图。默认值为vertical

# %%
x
# Out:
# array([6, 5, 0, 5, 9, 8, 9, 2, 0, 5])

# %%
x = np.random.randint(0,10,10)
plt.hist(x,normed=True,orientation='horizontal')
# Out:
# (array([ 0.33333333,  0.        ,  0.11111111,  0.11111111,  0.        ,
#          0.11111111,  0.        ,  0.11111111,  0.11111111,  0.22222222]),
#  array([ 0. ,  0.9,  1.8,  2.7,  3.6,  4.5,  5.4,  6.3,  7.2,  8.1,  9. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 条形图
#
# 【条形图有两个参数x,y！】
#
# bar()、barh()

# %%
x = np.linspace(0,5,5)
y = np.random.randint(0,20,size = 5)
plt.bar(x,y)
# Out:
# <Container object of 5 artists>

# %% [markdown]
# #### 水平条形图
# barh()

# %%
plt.barh(x,y)
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### 饼图
#
# 【饼图也只有一个参数x！】
#
# pie()
# 饼图适合展示各部分占总体的比例，条形图适合比较各部分的大小

# %% [markdown]
# 普通各部分占满饼图

# %%
p = np.array([0.7,0.2,0.1])

# plt.figure(figsize=(4,4))
plt.pie(p,labels=['dog','cat','orther'],autopct='%1.2f%%')
plt.axis('equal')
# Out:
# (-1.1173625220934387,
#  1.1008267867663541,
#  -1.1176888658268564,
#  1.1127701295901513)

# %% [markdown]
# 普通未占满饼图

# %%
p = np.array([0.6,0.2,0.1])

# plt.figure(figsize=(4,4))
plt.pie(p,labels=['dog','cat','orther'],autopct='%1.2f%%')
plt.axis('equal')
# Out:
# (-1.1129928305354353,
#  1.1006187062159731,
#  -1.1177383011956805,
#  1.1138080494567117)

# %% [markdown]
# 饼图阴影、分裂等属性设置
# #labels参数设置每一块的标签；labeldistance参数设置标签距离圆心的距离（比例值）
# #autopct参数设置比例值的显示格式(%1.1f%%)；pctdistance参数设置比例值文字距离圆心的距离
# #explode参数设置每一块顶点距圆形的长度（比例值）；colors参数设置每一块的颜色；
# #shadow参数为布尔值，设置是否绘制阴影

# %%
p = np.array([0.4,0.2,0.15,0.15,0.1])

# plt.figure(figsize=(4,4))
plt.pie(p,labels=['dog','cat','bird','cow','sheep'],
        labeldistance = 1.2,
        pctdistance = 0.5,
        explode = (0.2,0,0,0,0),
        shadow = True,
        autopct='%1.2f%%',
       startangle = 90)
plt.axis('equal')
# Out:
# (-1.3168414493940968,
#  1.1103257987825834,
#  -1.1030901801443624,
#  1.1648935655731008)

# %% [markdown]
# startangle设置旋转角度

# %% [markdown]
# ### 散点图
#
# 【散点图需要两个参数x,y，但此时x不是表示x轴的刻度，而是每个点的横坐标！】
#
# scatter()
# ![](10.png)

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
color = np.random.random(3000).reshape((1000,3))

size = np.random.randint(0,100,1000)

plt.scatter(x,y,color = color,s = size,marker = 'D')

# %% [markdown]
# ## <font color = red>四、图形内的文字、注释、箭头(自学)</font>

# %% [markdown]
# 控制文字属性的方法:
#
#
# | Pyplot函数     | API方法                | 描述                     |
# | :-------------: |:------------------------------:| :---------------------------------:|
# | text()       |  mpl.axes.Axes.text()       | 在Axes对象的任意位置添加文字     |
# | xlabel()      |  mpl.axes.Axes.set_xlabel()   | 为X轴添加标签               |
# | ylabel()      |  mpl.axes.Axes.set_ylabel()   | 为Y轴添加标签               |
# | title()       | mpl.axes.Axes.set_title()   |  为Axes对象添加标题            |
# | legend()      | mpl.axes.Axes.legend()      |  为Axes对象添加图例            |
# | figtext()     |  mpl.figure.Figure.text()    |  在Figure对象的任意位置添加文字    |
# | suptitle()     | mpl.figure.Figure.suptitle() |  为Figure对象添加中心化的标题     |
# | annnotate()    |  mpl.axes.Axes.annotate()    |  为Axes对象添加注释（箭头可选）    |
#
#
# 所有的方法会返回一个matplotlib.text.Text对象

# %% [markdown]
# ### 图形内的文字
# text()
# ![](14.png)

# %% [markdown]
# 使用figtext()

# %% [markdown]
# ### 注释
# annotate()
# xy参数设置箭头指示的位置，xytext参数设置注释文字的位置
# arrowprops参数以字典的形式设置箭头的样式
# width参数设置箭头长方形部分的宽度，headlength参数设置箭头尖端的长度，
# headwidth参数设置箭头尖端底部的宽度，shrink参数设置箭头顶点、尾部与指示点、注释文字的距离（比例值）
# ![](15.png)

# %% [markdown]
# 练习
# 三个随机正太分布数据
# ![](16.png)
# 设置图例
# bbox_to_anchor, mode,borderaxespad
# 设置注解

# %% [markdown]
# ### 箭头
# 箭头的样式，没必要记

# %%
plt.figure(figsize=(12,9))
plt.axis([0, 10, 0, 20]);
arrstyles = ['-', '->', '-[', '<-', '<->', 'fancy', 'simple', 'wedge']
for i, style in enumerate(arrstyles):
    plt.annotate(style, xytext=(1, 2+2*i), xy=(4, 1+2*i), arrowprops=dict(arrowstyle=style));

connstyles=["arc", "arc,angleA=10,armA=30,rad=30", "arc3,rad=.2", "arc3,rad=-.2", "angle", "angle3"]
for i, style in enumerate(connstyles):
    plt.annotate(style, xytext=(6, 2+2*i), xy=(8, 1+2*i), arrowprops=dict(arrowstyle='->', connectionstyle=style));
plt.show()

# %% [markdown]
# ## <font color = red>五、3D图(自学)</font>

# %% [markdown]
# #### 曲面图
# ![](11.png)

# %% [markdown]
# 导包
# from mpl_toolkits.mplot3d.axes3d import Axes3D

# %% [markdown]
# 生成数据

# %% [markdown]
# 绘制图形

# %% [markdown]
# ## <font color = red>玫瑰图/极坐标条形图(自学)</font>
# ![](13.png)

# %% [markdown]
# 创建极坐标条形图

# %% [markdown]
# 使用np.histogram计算一组数据的直方图
